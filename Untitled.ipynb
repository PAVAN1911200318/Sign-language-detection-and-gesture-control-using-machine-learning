# %%
# !pip install cvzone
# !pip install pyautogui
import cv2
from cvzone.HandTrackingModule import HandDetector
from cvzone.ClassificationModule import Classifier
import numpy as np
import math
import pyautogui
import time
import tensorflow as tf

# Check TensorFlow/Keras version
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)

# Paths to the model and labels
model_path = r"C:\Users\pavan\Desktop\COMPVSN\signLanguage_detection-main\Model\keras_model.h5"
labels_path = r"C:\Users\pavan\Desktop\COMPVSN\signLanguage_detection-main\Model\labels.txt"

# Initialize the classifier
classifier = Classifier(model_path, labels_path)

cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=1)
offset = 20
imgSize = 300
counter = 0

labels = ["Hello", "1", "2", "I love you"]

while True:
    success, img = cap.read()
    if not success:
        break

    imgOutput = img.copy()
    hands, img = detector.findHands(img)
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']

        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255

        imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]

        if imgCrop is None or imgCrop.size == 0:
            print("Image cropping failed or returned an empty result.")
            continue

        imgCropShape = imgCrop.shape

        aspectRatio = h / w

        if aspectRatio > 1:
            k = imgSize / h
            wCal = math.ceil(k * w)
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            imgResizeShape = imgResize.shape
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap: wCal + wGap] = imgResize
        else:
            k = imgSize / w
            hCal = math.ceil(k * h)
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            imgResizeShape = imgResize.shape
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap: hCal + hGap, :] = imgResize

        prediction, index = classifier.getPrediction(imgWhite, draw=False)
        gesture_label = labels[index]

        cv2.rectangle(imgOutput, (x - offset, y - offset - 70), (x - offset + 400, y - offset + 60 - 50), (0, 255, 0), cv2.FILLED)
        cv2.putText(imgOutput, labels[index], (x, y - 30), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 0), 2)
        cv2.rectangle(imgOutput, (x - offset, y - offset), (x + w + offset, y + h + offset), (0, 255, 0), 4)

        cv2.imshow('ImageCrop', imgCrop)
        cv2.imshow('ImageWhite', imgWhite)

        # Add volume control based on recognized gesture
        if gesture_label == "1":
            pyautogui.press("volumeup")
        elif gesture_label == "I love you":
            pyautogui.press("volumedown")

    cv2.imshow('Image', imgOutput)
    key = cv2.waitKey(1)
    if key == ord('q'):  # Press 'q' to exit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anaconda new\lib\site-packages)
# ...

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
import numpy as np
import math
import time
import os

cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=2)
offset = 20
imgSize = 300
counter = 0

folder = r"C:\Users\pavan\Desktop\COMPVSN\signLanguage_detection-main\data"

# Create the folder if it doesn't exist
if not os.path.exists(folder):
    os.makedirs(folder)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read from camera. Exiting...")
        break
    
    hands, img = detector.findHands(img)
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']

        # Ensure cropping coordinates are within image bounds
        y1, y2 = max(0, y - offset), min(img.shape[0], y + h + offset)
        x1, x2 = max(0, x - offset), min(img.shape[1], x + w + offset)
        
        imgCrop = img[y1:y2, x1:x2]

        if imgCrop.size == 0:
            print("Image cropping failed or returned an empty result.")
            time.sleep(1)  # add delay if you want
            continue

        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255

        aspectRatio = h / w

        if aspectRatio > 1:
            k = imgSize / h
            wCal = math.ceil(k * w)
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap:wCal + wGap] = imgResize
        else:
            k = imgSize / w
            hCal = math.ceil(k * h)
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap:hCal + hGap, :] = imgResize

        cv2.imshow('ImageCrop', imgCrop)
        cv2.imshow('ImageWhite', imgWhite)

    cv2.imshow('Image', img)
    key = cv2.waitKey(1)
    if key == ord("s"):
        counter += 1
        img_path = os.path.join(folder, f'Image_{time.time()}.jpg')
        cv2.imwrite(img_path, imgWhite)
        print(f"Saved: {img_path}")
        print(f"Image count: {counter}")
    elif key == ord("q"):  # you can exit anytime by pressing q
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
import numpy as np
import math
import time
import os

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Camera could not be opened.")
    exit()

detector = HandDetector(maxHands=2)
offset = 20
imgSize = 300
counter = 0

folder = r"C:\Users\pavan\Desktop\COMPVSN\signLanguage_detection-main\data"

# Create the folder if it doesn't exist
if not os.path.exists(folder):
    os.makedirs(folder)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read from camera.")
        break
    
    hands, img = detector.findHands(img)
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']

        # Ensure cropping coordinates are within image bounds
        y1, y2 = max(0, y - offset), min(img.shape[0], y + h + offset)
        x1, x2 = max(0, x - offset), min(img.shape[1], x + w + offset)
        
        imgCrop = img[y1:y2, x1:x2]

        if imgCrop.size == 0:
            print("Image cropping failed or returned an empty result.")
            time.sleep(1)  # add delay if you want
            continue

        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255

        aspectRatio = h / w

        if aspectRatio > 1:
            k = imgSize / h
            wCal = math.ceil(k * w)
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap:wCal + wGap] = imgResize
        else:
            k = imgSize / w
            hCal = math.ceil(k * h)
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap:hCal + hGap, :] = imgResize

        # Display the cropped and resized images
        cv2.imshow('ImageCrop', imgCrop)
        cv2.imshow('ImageWhite', imgWhite)

    # Display the original image with hand detection
    cv2.imshow('Image', img)

    key = cv2.waitKey(1)
    if key == ord("s"):
        counter += 1
        img_path = os.path.join(folder, f'Image_{time.time()}.jpg')
        cv2.imwrite(img_path, imgWhite)
        print(f"Saved: {img_path}")
        print(f"Image count: {counter}")
    elif key == ord("q"):  # you can exit anytime by pressing q
        break

cap.release()
cv2.destroyAllWindows()
